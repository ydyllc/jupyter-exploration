# %% [markdown]
# # My First Jupyter Notebook
#
# This is my first markdown cell in Jupyter using Google Colab. In this notebook, I am practicing how to write text, run Python code, and save a notebook for GitHub submission.

# %%
print("Hello, World!")
# Out:
# Hello, World!
